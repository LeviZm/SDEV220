# %%
# Module 4 - Exercises 20.1 - 20.4

# 20.1

import os

current_files = os.listdir('.')
print(f"Current directory files:\n {current_files}")
# Out:
# Current directory files: ['Module 4 - 17.4 - 17.8.ipynb', 'Module 4 20.1-20.4.ipynb']

# %%
# 20.2

parent_files = os.listdir('..')
print(f'Parent directory files: {parent_files}')
# Out:
# Parent directory files: ['.git', '.gitignore', 'Module 1', 'Module 2', 'Module 3', 'Module 4', 'README.md']

# %%
# 20.3

test1 = 'This is a test of the emergency text system'
with open('test.txt','wt') as outfile:
    outfile.write(test1)

# %%
# 20.4

with open('test.txt','rt') as infile:
    test2 = infile.read()

if test1 == test2:
    print('Success! test1 and test 2 are identical.')
else:
    print(f'Wait, something is different.')
# Out:
# Success! test1 and test 2 are identical.
