# %% [markdown]
# Again, the "oops" part of the code should never run.

# %%
# Module 2 - 7.3

guess_me = 5

for number in range(10):
    if number < guess_me:
        print("Too low")
    elif number == guess_me:
        print("Found it!")
        break
    else:
        print("Oops")
# Out:
# Too low
# Too low
# Too low
# Too low
# Too low
# Found it!
