# %%
# Module 2 - 6.2
# Step 1: Assign values
small = False
green = False

# Nested if statements to print the matching fruit to the boolean values of small and green
if small:
    if green:
        print("pea")
    else:
        print("cherry")
else:
    if green:
        print("watermelon")
    else:
        print("pumpkin")
# Out:
# pumpkin
