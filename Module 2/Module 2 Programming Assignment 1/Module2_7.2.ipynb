# %% [markdown]
# The "oops" part of this code should never run.

# %%
# Module 2 - 7.2

guess_me = 7
number = 1

while number != guess_me:
    print("too low")
    number += 1
    if number > guess_me:
        print("oops")
        break
else:
    print("found it!")
# Out:
# too low
# too low
# too low
# too low
# too low
# too low
# found it!
