# %% [markdown]
# Module 2 - Exercises 8.4 - 8.7

# %%
# Module 2 - 8.4
# Instructions are unclear, so I'm going to print the list two different ways

things = ["mozzarella", "cinderella", "salmonella"]

print(things) # will print the same way it appears above

for thing in things: # will loop through and print each item on a new line
    print(thing)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']
# mozzarella
# cinderella
# salmonella

# %%
# Modue 2 - 8.5

things[1].capitalize()
# Out:
# 'Cinderella'

# %%
print(things)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %% [markdown]
# No, things[1].capitalize() did not capitalize Cinderella in the list. It just printed Cinderella. When I added the print(things[1]) statement after, it was uncapitalized. I have to modify it at index one with an assignment statement to change the element in the list, as shown below.

# %%
things[1] = things[1].capitalize()

print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %%
things[0] = things[0].upper()

print(things)
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %%
things.pop(2)
things.append("Nobel Prize")
print(things)
# Out:
# ['mozzarella', 'cinderella', 'Nobel Prize']
