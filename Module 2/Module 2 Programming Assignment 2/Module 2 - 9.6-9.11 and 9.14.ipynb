# %% [markdown]
# Module 2 - Exercises 9.6-9.11 and 9.14

# %%
# Module 2 - 9.6 - 9.9

# 9.6

life = {
    'animals': {
        'cats': ['Henri', 'Grumpy', 'Lucy'],
        'octopi': {},
        'emus': {},
        },
    'plants':{},
    'other':{},
}

# 9.7

print(life.keys())

# 9.8

print(life['animals'].keys())

# 9.9

print(life['animals']['cats'])
# Out:
# <class 'dict'>
# <class 'dict'>
# dict_keys(['animals', 'plants', 'other'])
# dict_keys(['cats', 'octopi', 'emus'])
# ['Henri', 'Grumpy', 'Lucy']

# %%
# Module 2 - 9.10

squares = {key: key**2 for key in range(10)}

print(type(squares))
print(squares)
# Out:
# <class 'dict'>
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
# Module 2 - 9.11

odd = {value for value in range(10) if value % 2 != 0}

print(type(odd))
print(odd)
# Out:
# <class 'set'>
# {1, 3, 5, 7, 9}

# %%
# Module 2 - 9.14

titles = ['Creature of Habit', 'Crewel Fate', 'Sharks On a Plane']
plots = ['A nun turns into a monster', 'A haunted yarn shop', 'Check your exits']

print(type(titles))
print(type(plots))

movies = dict(zip(titles, plots))

print(movies)
# Out:
# <class 'list'>
# <class 'list'>
# {'Creature of Habit': 'A nun turns into a monster', 'Crewel Fate': 'A haunted yarn shop', 'Sharks On a Plane': 'Check your exits'}
