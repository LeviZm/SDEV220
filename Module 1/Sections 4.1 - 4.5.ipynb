# %%
# 4.1

song = """When an eel grabs your arm,
and it causes great harm,
that's - a moray!"""

updated_song = song.replace("moray", "Moray")

# %%
# 4.2

string_1 = "roast beef"
string_2 = "ham"
string_3 = "head"
string_4 = "clam"

poem = f'''My kitty cat likes {string_1},
my kitty cat likes {string_2},
my kitty cat fell on his {string_3}
and now he thinks he's a {string_4}.'''

print(poem)
# Out:
# My kitty cat likes roast beef,
# my kitty cat likes ham,
# my kitty cat fell on his head
# and now he thinks he's a clam.

# %%
# 4.3

letter = f'''Dear {salutation} {name},

Thank you for your letter. We are sorry that our {product} {verbed} in your {room}.
Please note that it should never be used in a {room}, especially near any {animals}.

Send us your receipt and {amount} for shipping and handling.
We will send you another {product} that, in our tests, is {percent}% less likely to have {verbed}.

Thank you for your support.

Sincerely,
{spokesman}
{job_title}'''

# %%
# 4.4

salutation = "Mr."
name = "Jones"
product = "lawnmower"
verbed = "exploded"
room = "living room"
animals = "dogs"
amount = "$10.00"
percent = "99.5"
spokesman = "Rick Roll"
job_title = "Customer Service Manager"

print(letter)
# Out:
# Dear Mr. Jones,
#
# Thank you for your letter. We are sorry that our lawnmower exploded in your living room.
# Please note that it should never be used in a living room, especially near any dogs.
#
# Send us your receipt and $10.00 for shipping and handling.
# We will send you another lawnmower that, in our tests, is 99.5% less likely to have exploded.
#
# Thank you for your support.
#
# Sincerely,
# Rick Roll
# Customer Service Manager

# %%
# 4.5

print(f'''After public polls to name things, a pattern emerged: an English submarine
(Boaty McBoatface), an Australian racehorse (Horsey McHorseface), and a
Swedish train (Trainy McTrainface).\n''')

winning_names = f'''Winning names at the state fair:
Prize duck (Ducky McDuckface)
Gourd (Gourdy McGourdface)
Spitz (Spitzy McSpitzface)'''

print(winning_names)
# Out:
# After public polls to name things, a pattern emerged: an English submarine
# (Boaty McBoatface), an Australian racehorse (Horsey McHorseface), and a
# Swedish train (Trainy McTrainface).
#
# Winning names at the state fair:
# Prize duck (Ducky McDuckface)
# Gourd (Gourdy McGourdface)
# Spitz (Spitzy McSpitzface)
